# %% [markdown]
# ## LIB

# %%
# === LIB ===
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.integrate import quad
from scipy.optimize import minimize
from datetime import datetime as dt

from nelson_siegel_svensson import NelsonSiegelSvenssonCurve
from nelson_siegel_svensson.calibrate import calibrate_nss_ols

# ---------------- Heston risk–neutral senza lambda ----------------
def heston_charfunc(phi, S0, v0, kappaQ, thetaQ, xi, rho, tau, r):
    a = kappaQ * thetaQ
    b = kappaQ                      # niente lambda in Q
    rspi = rho * xi * phi * 1j
    d = np.sqrt((rspi - b)**2 + (phi*1j + phi**2) * xi**2)
    g = (b - rspi + d) / (b - rspi - d)

    exp1 = np.exp(r * phi * 1j * tau)
    term2 = S0**(phi*1j) * ((1 - g*np.exp(d*tau)) / (1 - g))**(-2*a/xi**2)
    exp2 = np.exp(a*tau*(b - rspi + d)/xi**2 + v0*(b - rspi + d)*((1 - np.exp(d*tau))/(1 - g*np.exp(d*tau)))/xi**2)
    return exp1 * term2 * exp2

def _integrand(phi, S0, K, v0, kappaQ, thetaQ, xi, rho, tau, r):
    args = (S0, v0, kappaQ, thetaQ, xi, rho, tau, r)
    num = np.exp(r*tau)*heston_charfunc(phi-1j, *args) - K*heston_charfunc(phi, *args)
    den = 1j*phi*K**(1j*phi)
    return num/den  # complesso

def heston_price_rec(S0, K, v0, kappaQ, thetaQ, xi, rho, tau, r, umax=100.0, N=10000):
    args = (S0, v0, kappaQ, thetaQ, xi, rho, tau, r)
    P = 0.0
    dphi = umax / N
    for i in range(1, N):
        phi = dphi * (2*i + 1) / 2
        num = np.exp(r*tau)*heston_charfunc(phi-1j, *args) - K*heston_charfunc(phi, *args)
        den = 1j*phi*K**(1j*phi)
        P += dphi * num/den
    return float(np.real((S0 - K*np.exp(-r*tau))/2 + P/np.pi))

def heston_price(S0, K, v0, kappaQ, thetaQ, xi, rho, tau, r):
    real_val, err = quad(lambda u: np.real(_integrand(u, S0, K, v0, kappaQ, thetaQ, xi, rho, tau, r)),
                         0.0, 100.0, limit=200)
    return float((S0 - K*np.exp(-r*tau))/2 + real_val/np.pi)

# --- test rapido ---
if __name__ == "__main__":
    S0, K = 100.0, 100.0
    v0, r = 0.1, 0.03
    kappaQ, thetaQ, xi, rho = 1.5768, 0.0398, 0.3, -0.5711
    tau = 1.0
    price = heston_price(S0, K, v0, kappaQ, thetaQ, xi, rho, tau, r)
    print("[TEST HESTON Q, no lambda] price =", price)
# Out:
# [TEST HESTON Q, no lambda] price = 12.422227179891545

# %% [markdown]
# ## RATE

# %%
# === RATE ===
yield_maturities = np.array([1/12, 1.5/12, 2/12, 3/12, 4/12, 6/12, 1, 2, 3, 5, 7, 10, 20, 30])
yields = np.array([4.18, 4.15, 4.08, 4.00, 3.95, 3.79, 3.56, 3.46, 3.47, 3.59, 3.78, 4.02, 4.58, 4.60]).astype(float) / 100
curve_fit, status = calibrate_nss_ols(yield_maturities, yields)
curve_fit
# Out:
# NelsonSiegelSvenssonCurve(beta0=np.float64(0.04898343382138078), beta1=np.float64(-0.007002110250220919), beta2=np.float64(-0.04091844716803696), beta3=np.float64(0.0036452471208201294), tau1=np.float64(2.0), tau2=np.float64(5.0))

# %% [markdown]
# ## IB

# %%
# === PARTE A: FETCH IB (con timestamp robusti e close di ieri) ===
import json, math, random, re, time
from typing import Iterable, List, Tuple, Optional
import numpy as np, pandas as pd
from ib_insync import IB, Stock, Option, util, BarData

TICKER = "MSTR"
USE_ALL_FUTURE_EXPIRIES = True
DATES_IT = []
OUT_PREFIX = "mstr_panel"
RISK_FREE = 0.035
DIV_YIELD = 0.0
NY_TZ = "America/New_York"

# ---------------- UTILS ----------------
def _to_ny(ts):
    t = pd.Timestamp(ts)
    return t.tz_localize(NY_TZ) if t.tzinfo is None else t.tz_convert(NY_TZ)

def yearfrac_365(start_ts, end_ts) -> float:
    s, e = _to_ny(start_ts), _to_ny(end_ts)
    return (e - s).total_seconds() / (365.0 * 24 * 3600.0)

_IT_MONTH = {"gen":1,"feb":2,"mar":3,"apr":4,"mag":5,"giu":6,"lug":7,"ago":8,"set":9,"ott":10,"nov":11,"dic":12}
def parse_user_expiries_it(user_expiries_it: Iterable[str]) -> List[pd.Timestamp]:
    out=[]
    for s in user_expiries_it:
        s=s.strip().lower().replace("’","'").replace("  "," ")
        m=re.match(r"(\d{1,2})\s+([a-z]{3})\s+(\d{2,4})", s)
        if not m: continue
        d, mon, y = int(m.group(1)), _IT_MONTH[m.group(2)], int(m.group(3))
        if y < 100: y += 2000
        ts=_to_ny(pd.Timestamp(year=y,month=mon,day=d))+pd.Timedelta(hours=16)
        out.append(ts)
    return sorted(set(out))

SUPPRESS_IB_CODES = {10089,10090,10091,10167,2104}
def setup_marketdata_mode(ib: IB):
    # prova realtime, poi delayed, poi frozen
    def _quiet(reqId, code, msg, contract):
        if code in SUPPRESS_IB_CODES: return
        print(f"IB Error {code}, reqId {reqId}: {msg}")
    try: ib.errorEvent.clear()
    except Exception: pass
    ib.errorEvent += _quiet
    for mkt_type in (1, 3, 4):
        try:
            ib.reqMarketDataType(mkt_type)
            break
        except Exception:
            continue

def connect_ib(host="127.0.0.1", port=7497, client_id=None) -> IB:
    util.startLoop()
    ib=IB()
    ids = ([client_id]+[i for i in range(2,199) if i!=client_id]) if client_id is not None else list(range(2,199))
    random.shuffle(ids)
    last=None
    for cid in ids:
        try:
            ib.connect(host,port,clientId=cid,readonly=True,timeout=10)
            if not ib.isConnected():
                raise TimeoutError("API connection failed")
            setup_marketdata_mode(ib)
            return ib
        except Exception as e:
            last=e
            try: ib.disconnect()
            except: pass
    raise RuntimeError(f"Connessione IB fallita. Ultimo errore: {last}")

# ---------------- EXPIRIES ----------------
def list_future_expiries(ib: IB, ticker: str, max_years: float = 5.0) -> List[pd.Timestamp]:
    stk = ib.qualifyContracts(Stock(ticker, "SMART", "USD"))[0]
    params = ib.reqSecDefOptParams(stk.symbol, "", stk.secType, stk.conId)
    expirations_raw = set()
    for p in params:
        if getattr(p, "expirations", None):
            expirations_raw.update(p.expirations)
    if not expirations_raw:
        raise RuntimeError("Nessuna expiration ricevuta da IB.")

    def _parse_exp(s: str) -> Optional[pd.Timestamp]:
        s = str(s).strip()
        clean = re.sub(r"[^0-9\-]", "", s)
        if re.fullmatch(r"\d{8}", clean):
            dt = pd.to_datetime(clean, format="%Y%m%d", errors="coerce")
        else:
            dt = pd.to_datetime(clean, errors="coerce")
        if pd.isna(dt): return None
        return _to_ny(dt) + pd.Timedelta(hours=16)

    today_ny = _to_ny(pd.Timestamp.now("UTC")).normalize()
    cutoff = today_ny + pd.Timedelta(days=int(max_years*365))
    out = [ts for s in expirations_raw if (ts := _parse_exp(s)) and today_ny <= ts <= cutoff]
    out = sorted(set(out))
    if not out:
        raise RuntimeError("Nessuna scadenza futura disponibile dopo il filtro.")
    return out

# ---------------- SPOT & PRICES ----------------
def _finite_pos(x) -> bool:
    try:
        return math.isfinite(x) and float(x) > 0
    except Exception:
        return False

def _pick_px_from_ticker(tk) -> Optional[float]:
    if _finite_pos(getattr(tk, "last", float("nan"))):   return float(tk.last)
    if _finite_pos(getattr(tk, "close", float("nan"))):  return float(tk.close)
    b = getattr(tk, "bid", float("nan")); a = getattr(tk, "ask", float("nan"))
    if _finite_pos(b) and _finite_pos(a): return 0.5*(float(b)+float(a))
    if _finite_pos(b):                    return float(b)
    if _finite_pos(a):                    return float(a)
    try:
        mp = tk.marketPrice()
        if _finite_pos(mp):              return float(mp)
    except Exception:
        pass
    return None

def _hist_latest_bar(ib: IB, stk: Stock, days=7, bar="5 mins", what="TRADES", useRTH=False):
    try:
        bars: List[BarData] = ib.reqHistoricalData(
            stk, endDateTime="", durationStr=f"{days} D",
            barSizeSetting=bar, whatToShow=what,
            useRTH=useRTH, formatDate=1, keepUpToDate=False
        )
        if bars:
            last = bars[-1]
            return float(last.close), pd.Timestamp(last.date, tz="UTC")
    except Exception:
        pass
    return None, None

def _yesterday_close(ib: IB, stk: Stock):
    bars = ib.reqHistoricalData(
        stk, endDateTime="", durationStr="6 D",
        barSizeSetting="1 day", whatToShow="TRADES",
        useRTH=True, formatDate=1, keepUpToDate=False
    )
    if not bars or len(bars) < 1:
        raise RuntimeError("Daily history insufficiente.")
    last = bars[-1]              # ultimo giorno di negoziazione RTH disponibile
    return float(last.close), pd.Timestamp(last.date, tz="UTC")

def fetch_spot_ref(ib: IB, ticker="MSTR") -> Tuple[float, pd.Timestamp, str, float, pd.Timestamp]:
    """
    Restituisce:
      S0, spot_ts_utc, source ('live'|'historical'|'historical_daily'), y_close, y_close_ts_utc
    """
    stk = ib.qualifyContracts(Stock(ticker,"SMART","USD"))[0]

    # 1) tentativo live snapshot
    for wait in (2.5, 3.5):
        try:
            tk = ib.reqMktData(stk,"",snapshot=True,regulatorySnapshot=False)
            ib.sleep(wait)
            px = _pick_px_from_ticker(tk)
            if px is not None:
                ypx, yts = _yesterday_close(ib, stk)
                return float(px), pd.Timestamp.now("UTC"), "live", ypx, yts
        except Exception:
            pass

    # 2) fallback storico più recente
    candidates=[]
    for what in ("TRADES","MIDPOINT","BID","ASK"):
        for useRTH in (False, True):
            px, ts = _hist_latest_bar(ib, stk, days=7, bar="5 mins", what=what, useRTH=useRTH)
            if px is not None and ts is not None:
                candidates.append((ts, px))
    if candidates:
        ts, px = max(candidates, key=lambda t: t[0])
        ypx, yts = _yesterday_close(ib, stk)
        return float(px), ts, "historical", ypx, yts

    # 3) daily RTH come ultima risorsa
    ypx, yts = _yesterday_close(ib, stk)
    return float(ypx), yts, "historical_daily", ypx, yts

# --- estrai timestamp trade da generic tick 375 (RTVolume) ---
def _extract_last_ts_from_rtvolume(tk) -> Optional[pd.Timestamp]:
    try:
        s = tk.rtVolume  # formato: "lastSize;lastTime;totalVolume;vwap;singleTrade;..."
        if not s: return None
        parts = str(s).split(";")
        if len(parts) >= 2:
            ms = int(parts[1])
            return pd.Timestamp(ms, unit="ms", tz="UTC")
    except Exception:
        pass
    return None

# ---------------- FETCH CHAIN ----------------
def _option_px_from_ticker(tk):
    vals=[]
    try:
        mg=tk.modelGreeks
        if mg and _finite_pos(getattr(mg,"optPrice", float("nan"))): vals.append(float(mg.optPrice))
    except Exception:
        pass
    b=getattr(tk,"bid",float("nan")); a=getattr(tk,"ask",float("nan"))
    if _finite_pos(b) and _finite_pos(a): vals.append(0.5*(b+a))
    if _finite_pos(getattr(tk,"last",float("nan"))):  vals.append(float(tk.last))
    if _finite_pos(getattr(tk,"close",float("nan"))): vals.append(float(tk.close))
    if _finite_pos(b): vals.append(float(b))
    if _finite_pos(a): vals.append(float(a))
    return float(vals[0]) if vals else float("nan")

def fetch_chain_fixed_strikes(
    ib: IB,
    ticker: str,
    expiries_ts: List[pd.Timestamp],
    strikes = tuple(np.arange(100.0, 900.0+1e-9, 10.0)),
    include_calls=True,
    include_puts=True,
    sleep_seconds=4.8,
    passes_per_expiry=2,
    batch_size=18,
    generic_ticks="106,375"  # 106=Option Computation, 375=RTVolume per timestamp
) -> pd.DataFrame:
    stk = ib.qualifyContracts(Stock(ticker, "SMART", "USD"))[0]
    S0, spot_ts, source, y_close, y_close_ts = fetch_spot_ref(ib, ticker)
    today_ny = _to_ny(pd.Timestamp.now("UTC")).normalize()

    rights=[]
    if include_calls: rights.append("C")
    if include_puts:  rights.append("P")

    rows=[]; report=[]
    for exp_ts in expiries_ts:
        T = yearfrac_365(today_ny, exp_ts)
        if T <= 0:
            report.append((exp_ts.strftime("%Y-%m-%d"), 0, "T<=0")); continue

        expiry_ymd = exp_ts.strftime("%Y%m%d")
        contracts = [
            Option(symbol=stk.symbol,
                   lastTradeDateOrContractMonth=expiry_ymd,
                   strike=float(k),
                   right=r,
                   exchange="SMART",
                   currency="USD",
                   tradingClass=stk.symbol)
            for r in rights for k in strikes
        ]

        qualified = ib.qualifyContracts(*contracts)
        got_before_total = len(rows)

        for _ in range(passes_per_expiry):
            for i in range(0, len(qualified), batch_size):
                qs = qualified[i:i+batch_size]
                tks = [ib.reqMktData(c, generic_ticks, snapshot=False, regulatorySnapshot=False) for c in qs]
                ib.sleep(sleep_seconds)
                for c, tk in zip(qs, tks):
                    px = _option_px_from_ticker(tk)
                    ts_tick = _extract_last_ts_from_rtvolume(tk)  # timestamp trade più recente
                    if math.isfinite(px) and px>0:
                        rows.append(dict(
                            right=c.right,
                            K=float(c.strike),
                            expiry_iso=str((_to_ny(pd.Timestamp(c.lastTradeDateOrContractMonth))+pd.Timedelta(hours=16)).isoformat()),
                            T=T,
                            close=float(px),
                            conId=c.conId,
                            symbol=c.localSymbol,
                            last_trade_ts_utc=str(ts_tick) if ts_tick is not None else None
                        ))
                for tk in tks:
                    try: ib.cancelMktData(tk)
                    except Exception: pass
                time.sleep(0.25)

        found = len(rows) - got_before_total
        report.append((exp_ts.strftime("%Y-%m-%d"), found, f"requested={len(qualified)}"))

    if not rows:
        raise RuntimeError("Nessuna quotazione valida.")

    df = (pd.DataFrame(rows)
            .drop_duplicates(subset=["conId"])
            .sort_values(["expiry_iso","right","K"])
            .reset_index(drop=True))
    df.attrs["S0"]=S0
    df.attrs["spot_ts"]=spot_ts
    df.attrs["source"]=source
    df.attrs["y_close"]=y_close
    df.attrs["y_close_ts"]=y_close_ts
    return df

# ---------------- PIPELINE ----------------
def run_pipeline(ticker=TICKER, dates_it=DATES_IT, out_prefix=OUT_PREFIX, sleep_seconds=4.8):
    ib=connect_ib()
    try:
        if USE_ALL_FUTURE_EXPIRIES:
            exps = list_future_expiries(ib, ticker)
        else:
            exps = parse_user_expiries_it(dates_it)
        if not exps:
            raise RuntimeError("Lista scadenze vuota/non valida.")

        df=fetch_chain_fixed_strikes(
            ib, ticker, exps,
            strikes=tuple(np.arange(100.0, 900.0+1e-9, 10.0)),
            include_calls=True, include_puts=True,
            sleep_seconds=sleep_seconds,
            passes_per_expiry=2
        )

        as_of_ny = str(_to_ny(pd.Timestamp.now("UTC")).normalize().date())

        meta={
            "ticker": ticker,
            "S0": float(df.attrs["S0"]),
            "spot_ts": str(df.attrs["spot_ts"]),            # timestamp effettivo dello spot usato
            "as_of_ny": as_of_ny,                           # data di riferimento NY
            "source": df.attrs["source"],                   # live/historical/historical_daily
            "y_close": float(df.attrs["y_close"]),          # close RTH ultimo giorno
            "y_close_ts": str(df.attrs["y_close_ts"]),
            "r": RISK_FREE,
            "q": DIV_YIELD
        }

        df.to_csv(f"{out_prefix}_chain.csv", index=False)
        with open(f"{out_prefix}_meta.json", "w") as f:
            json.dump(meta, f, indent=2)

        print(f"[FETCH] n={len(df)}  S0={meta['S0']:.4f}  -> {out_prefix}_chain.csv / _meta.json")
        print(f"[INFO] Spot source={meta['source']}  spot_ts(UTC)={meta['spot_ts']}  y_close={meta['y_close']:.4f}")
        print("[NOTE] Ogni riga opzione ha 'last_trade_ts_utc' se il timestamp del trade è disponibile.")
    finally:
        try: ib.disconnect()
        except Exception: pass

if __name__ == "__main__":
    run_pipeline()
# Out:
# Error 200, reqId 9: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=100.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 10: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=110.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 11: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=120.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# IB Error 200, reqId 9: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 10: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 11: Nessuna descrizione di titoli trovata per la richiesta
# Error 200, reqId 12: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=130.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 13: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=140.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# IB Error 200, reqId 12: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 13: Nessuna descrizione di titoli trovata per la richiesta
# Error 200, reqId 66: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=670.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 67: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=680.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 68: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=690.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 69: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=700.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 72: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=730.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 70: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=710.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 71: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=720.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 73: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=740.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 74: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=750.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 76: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=770.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 75: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=760.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 79: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=800.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 77: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=780.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 78: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=790.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 80: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=810.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 81: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=820.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# IB Error 200, reqId 66: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 67: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 68: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 69: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 72: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 70: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 71: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 73: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 74: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 76: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 75: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 79: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 77: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 78: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 80: Nessuna descrizione di titoli trovata per la richiesta
# Error 200, reqId 82: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=830.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 83: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=840.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 84: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=850.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 85: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=860.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 86: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=870.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 88: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=890.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 87: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=880.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 89: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=900.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 90: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=100.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 91: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=110.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 92: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=120.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 94: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=140.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 93: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=130.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# IB Error 200, reqId 81: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 82: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 83: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 84: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 85: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 86: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 88: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 87: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 89: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 90: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 91: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 92: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 94: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 93: Nessuna descrizione di titoli trovata per la richiesta
# Error 200, reqId 147: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=670.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 148: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=680.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 149: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=690.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# IB Error 200, reqId 147: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 148: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 149: Nessuna descrizione di titoli trovata per la richiesta
# Error 200, reqId 150: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=700.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 153: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=730.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 152: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=720.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 151: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=710.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 154: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=740.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 156: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=760.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 155: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=750.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 157: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=770.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 160: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=800.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 158: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=780.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 159: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=790.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 161: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=810.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# IB Error 200, reqId 150: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 153: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 152: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 151: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 154: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 156: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 155: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 157: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 160: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 158: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 159: Nessuna descrizione di titoli trovata per la richiesta
# Error 200, reqId 163: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=830.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 162: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=820.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 165: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=850.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 164: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=840.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 166: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=860.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 167: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=870.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 169: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=890.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# IB Error 200, reqId 161: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 163: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 162: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 165: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 164: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 166: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 167: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 169: Nessuna descrizione di titoli trovata per la richiesta
# Error 200, reqId 168: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=880.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Error 200, reqId 170: Nessuna descrizione di titoli trovata per la richiesta, contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=900.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=100.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=110.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=120.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=130.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=140.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=670.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=680.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=690.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=700.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=710.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=720.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=730.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=740.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=750.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=760.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=770.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=780.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=790.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=800.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=810.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=820.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=830.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=840.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=850.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=860.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=870.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=880.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=890.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=900.0, right='C', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=100.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=110.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=120.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=130.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=140.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=670.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=680.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=690.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=700.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=710.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=720.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=730.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=740.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=750.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=760.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=770.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=780.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=790.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=800.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=810.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=820.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=830.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=840.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=850.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=860.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=870.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=880.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=890.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# Unknown contract: Option(symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=900.0, right='P', exchange='SMART', currency='USD', tradingClass='MSTR')
# IB Error 200, reqId 168: Nessuna descrizione di titoli trovata per la richiesta
# IB Error 200, reqId 170: Nessuna descrizione di titoli trovata per la richiesta
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812379278, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=150.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00150000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 170673, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=134.95, bidGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), askGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), lastGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), modelGreeks=OptionComputation(tickAttrib=0, impliedVol=3.932407591068941, delta=0.9993957969832368, optPrice=134.70019713481494, pvDividend=0.0, gamma=3.590929257048496e-05, vega=0.0003246263286200701, theta=-0.03017999281377115, undPrice=284.7300109863281), bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812379348, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=160.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00160000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 170673, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=124.95, bidGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), askGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), lastGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), modelGreeks=OptionComputation(tickAttrib=0, impliedVol=3.748236764364548, delta=0.998859739084415, optPrice=124.71044771179106, pvDividend=0.0, gamma=6.759317440588303e-05, vega=0.0006229673598596719, theta=-0.04043032225746401, undPrice=284.7300109863281), bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812379411, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=170.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00170000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 171873, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=114.96, bidGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), askGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), lastGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), modelGreeks=OptionComputation(tickAttrib=0, impliedVol=3.3817297819019383, delta=0.9988030521681972, optPrice=114.89076914948345, pvDividend=0.0, gamma=7.870961107046262e-05, vega=0.0006427984955053034, theta=-0.040637555572303086, undPrice=284.7300109863281), bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812379459, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=180.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00180000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 171873, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=104.96, bidGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), askGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), lastGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), modelGreeks=OptionComputation(tickAttrib=0, impliedVol=3.0463263383823125, delta=0.998534711541524, optPrice=104.89425445856142, pvDividend=0.0, gamma=0.00010466909039572504, vega=0.0006617788397136337, theta=-0.04412266353094196, undPrice=284.7300109863281), bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812379520, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=190.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00190000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 171873, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=94.96, bidGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), askGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), lastGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), modelGreeks=OptionComputation(tickAttrib=0, impliedVol=2.74036609917813, delta=0.9981435291545542, optPrice=94.71864446213628, pvDividend=0.0, gamma=0.00014419936168950484, vega=0.001208884462286619, theta=-0.04862633000786331, undPrice=284.7300109863281), bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812379580, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=200.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00200000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 171873, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=84.98, bidGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), askGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), lastGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), modelGreeks=OptionComputation(tickAttrib=0, impliedVol=2.490910460745491, delta=0.9972588362351418, optPrice=84.72888957671255, pvDividend=0.0, gamma=0.0002255490113758432, vega=0.0012406453121798222, theta=-0.05887119705145949, undPrice=284.7300109863281), bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812379634, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=210.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00210000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 14, 887999, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=74.99, bidGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), askGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), lastGreeks=OptionComputation(tickAttrib=0, impliedVol=None, delta=None, optPrice=None, pvDividend=0.0, gamma=None, vega=-2.0, theta=-2.0, undPrice=289.15000000000003), modelGreeks=OptionComputation(tickAttrib=0, impliedVol=2.2723745629931784, delta=0.9957523599962008, optPrice=74.74497064147924, pvDividend=0.0, gamma=0.00036820543583600913, vega=0.002165189942203938, theta=-0.07495201428807263, undPrice=284.7300109863281), bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812379698, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=220.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00220000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 440131, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=65.01, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812379834, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=230.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00230000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 440131, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=55.03, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812379964, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=240.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00240000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 441224, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=45.04, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812380064, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=250.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00250000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 440131, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=35.06, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812380159, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=260.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00260000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 440131, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=25.15, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811850751, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=270.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00270000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 440131, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=15.54, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811850890, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=280.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00280000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 441224, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=7.44, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811851031, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=290.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00290000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 440131, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=2.57, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811851140, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=300.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00300000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 440131, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.69, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811851298, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=310.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00310000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 443803, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.24, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811851429, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=320.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00320000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 15, 444917, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.13, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811851546, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=330.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00330000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 166458, tzinfo=datetime.timezone.utc), minTick=0.0, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.08, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811851671, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=340.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00340000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 298122, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.07, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811851808, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=350.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00350000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 298122, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.05, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811851931, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=360.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00360000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 298122, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.04, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811852055, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=370.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00370000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 298122, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.03, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811852176, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=380.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00380000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 298122, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.02, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811852308, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=390.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00390000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 298122, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.01, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=811852429, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=400.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00400000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 298122, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.0, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812380377, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=410.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00410000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 298122, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.0, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812380476, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=420.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00420000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 430123, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.0, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812380586, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=430.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00430000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 430123, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.0, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812380675, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=440.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00440000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 19, 437046, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.0, bboExchange='c70003', snapshotPermissions=3)
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=812380783, symbol='MSTR', lastTradeDateOrContractMonth='20251024', strike=450.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  251024C00450000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 6, 20, 155794, tzinfo=datetime.timezone.utc), minTick=0.0, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=0.0, bboExchange='c70003')
# ...
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247396, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=420.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00420000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 72431, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=188.75, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247451, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=430.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00430000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 72431, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=196.41, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247509, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=440.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00440000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 178002, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=204.21, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247575, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=450.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00450000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 178002, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=212.09, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247641, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=460.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00460000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 178002, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=220.03, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247696, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=470.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00470000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 274804, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=228.05, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247759, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=480.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00480000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 274804, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=236.15, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247819, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=490.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00490000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 371955, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=244.33, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247869, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=500.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00500000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 476323, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=252.62, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247932, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=510.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00510000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 578949, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=260.92, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816247984, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=520.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00520000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 677832, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=269.33, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248037, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=530.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00530000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 775248, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=277.75, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248084, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=540.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00540000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 871090, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=286.28, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248142, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=550.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00550000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 53, 976647, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=294.83, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248194, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=560.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00560000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 54, 71745, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=303.39, halted=0.0, ticks=[TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 54, 71745, tzinfo=datetime.timezone.utc), tickType=8, price=-1.0, size=0.0), TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 54, 71745, tzinfo=datetime.timezone.utc), tickType=9, price=303.39, size=0.0), TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 54, 71745, tzinfo=datetime.timezone.utc), tickType=49, price=0.0, size=0), TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 54, 71745, tzinfo=datetime.timezone.utc), tickType=49, price=0.0, size=0)], bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248244, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=570.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00570000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 122314, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=312.07, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248299, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=580.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00580000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 122314, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=320.77, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248363, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=590.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00590000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 122314, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=329.54, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248416, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=600.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00600000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 122314, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=338.32, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248469, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=610.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00610000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 222285, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=347.2, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248522, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=620.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00620000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 222593, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=356.09, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248557, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=630.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00630000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 321541, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=365.04, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248613, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=640.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00640000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 423858, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=374.0, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248673, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=650.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00650000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 521216, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=383.0, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248704, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=660.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00660000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 621125, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=392.0, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248758, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=670.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00670000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 722614, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=401.07, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248812, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=680.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00680000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 821111, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=410.18, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248869, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=690.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00690000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 58, 924117, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=419.29, halted=0.0, bboExchange='c70003')
# cancelMktData: No reqId found for contract Ticker(contract=Option(conId=816248920, symbol='MSTR', lastTradeDateOrContractMonth='20280121', strike=700.0, right='P', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSTR  280121P00700000', tradingClass='MSTR'), time=datetime.datetime(2025, 10, 24, 8, 33, 59, 21191, tzinfo=datetime.timezone.utc), minTick=0.01, bid=-1.0, bidSize=0.0, ask=-1.0, askSize=0.0, volume=0.0, close=428.53, halted=0.0, ticks=[TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 59, 21191, tzinfo=datetime.timezone.utc), tickType=8, price=-1.0, size=0.0), TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 59, 21191, tzinfo=datetime.timezone.utc), tickType=9, price=428.53, size=0.0), TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 59, 21191, tzinfo=datetime.timezone.utc), tickType=49, price=0.0, size=0), TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 59, 21191, tzinfo=datetime.timezone.utc), tickType=8, price=-1.0, size=0.0), TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 59, 21191, tzinfo=datetime.timezone.utc), tickType=9, price=428.53, size=0.0), TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 59, 21191, tzinfo=datetime.timezone.utc), tickType=49, price=0.0, size=0), TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 59, 21191, tzinfo=datetime.timezone.utc), tickType=49, price=0.0, size=0), TickData(time=datetime.datetime(2025, 10, 24, 8, 33, 59, 21191, tzinfo=datetime.timezone.utc), tickType=49, price=0.0, size=0)], bboExchange='c70003')
# [FETCH] n=2684  S0=289.1500  -> mstr_panel_chain.csv / _meta.json
# [INFO] Spot source=live  spot_ts(UTC)=2025-10-24 08:06:09.193154+00:00  y_close=284.9200
# [NOTE] Ogni riga opzione ha 'last_trade_ts_utc' se il timestamp del trade è disponibile.

# %% [markdown]
# ## PULIZIA E NODI

# %%
# === PARTE A.2: CLEANING & NODI ===
import json, numpy as np, pandas as pd
from math import exp

try:
    OUT_PREFIX
except NameError:
    OUT_PREFIX = "mstr_panel"

T_AVAILABLE = np.array([
    0.021,0.040,0.059,0.098,0.194,0.270,0.347,0.443,
    0.520,0.596,1.018,1.268,1.344,1.763,2.016,2.25
], float)

M_CORE = np.array([0.90,1.00,1.10,1.25], float)
M_WING = np.array([1.50,1.75,2.00], float)

def _first_existing(df, names):
    for n in names:
        if n in df.columns:
            return n
    return None

def _yearfrac_365(start_ts, end_ts):
    s = pd.to_datetime(start_ts, utc=True, errors="coerce")
    e = pd.to_datetime(end_ts,   utc=True, errors="coerce")
    return (e - s).total_seconds() / (365.0*24*3600.0)

def _ensure_T(df, meta):
    tcol = _first_existing(df, ["T","tau","ttm","time_to_maturity","maturity_years","T_years"])
    if tcol:
        df = df.rename(columns={tcol:"T"}).copy()
        df["T"] = pd.to_numeric(df["T"], errors="coerce")
        return df.loc[np.isfinite(df["T"])].copy()
    dcol = _first_existing(df, ["days_to_expiry","daysToExpiry","DTE","dte"])
    if dcol:
        df = df.copy()
        df["T"] = pd.to_numeric(df[dcol], errors="coerce")/365.0
        return df.loc[np.isfinite(df["T"])].copy()
    exp_col = _first_existing(df, ["expiry_iso","expiry","expiration","expiryISO","lastTradeDateOrContractMonth","expiryYmd"])
    if exp_col is None:
        raise KeyError("Impossibile derivare T: nessuna colonna T/DTE/expiry trovata.")
    exp = df[exp_col].astype(str)
    mask_ymd  = exp.str.fullmatch(r"\d{8}")
    exp2 = exp.copy()
    exp2.loc[mask_ymd] = exp.loc[mask_ymd] + " 16:00"
    mask_date = exp2.str.fullmatch(r"\d{4}-\d{2}-\d{2}")
    exp2.loc[mask_date] = exp2.loc[mask_date] + " 16:00"
    spot_ts = meta.get("spot_ts", pd.Timestamp.now("UTC").isoformat())
    df = df.copy()
    df["T"] = exp2.apply(lambda x: _yearfrac_365(spot_ts, x))
    df["T"] = pd.to_numeric(df["T"], errors="coerce")
    return df.loc[np.isfinite(df["T"])].copy()

def clean_chain_for_calibration(
    chain_csv=f"{OUT_PREFIX}_chain.csv",
    meta_json=f"{OUT_PREFIX}_meta.json",
    out_csv=f"{OUT_PREFIX}_calls_clean.csv",
    out_report=f"{OUT_PREFIX}_clean_report.json",
    out_nodes_csv=f"{OUT_PREFIX}_calib_nodes.csv",
    use_calls=True,
    K_range=(200.0,800.0),
    T_range=(1/365,5.0),
    price_floor=1e-3,
    price_cap_mult=1.05,
    min_strikes_per_expiry=10,
    drop_dupes=True,
    enforce_monotonic_K=True,
    T_tolerance=0.05
):
    df = pd.read_csv(chain_csv)
    meta = json.load(open(meta_json))

    K_col      = _first_existing(df, ["K","strike","Strike","STRIKE"])
    price_col  = _first_existing(df, ["close","price","last","settle","optPrice","C","call_price","call_mid"])
    right_col  = _first_existing(df, ["right","cp","optionRight"])
    expiry_col = _first_existing(df, ["expiry_iso","expiry","expiration","expiryISO","lastTradeDateOrContractMonth","expiryYmd"])

    if K_col is None or price_col is None:
        raise KeyError("Mancano colonne essenziali: K o prezzo (es. close/price).")

    df = df.rename(columns={K_col:"K", price_col:"close"}).copy()
    if right_col:  df = df.rename(columns={right_col:"right"})
    if expiry_col: df = df.rename(columns={expiry_col:"expiry_iso"})

    df["K"] = pd.to_numeric(df["K"], errors="coerce")
    df["close"] = pd.to_numeric(df["close"], errors="coerce")

    df = _ensure_T(df, meta)
    if "T" not in df.columns:
        raise KeyError("Colonna T assente dopo _ensure_T.")

    if use_calls and "right" in df.columns:
        df = df[df["right"]=="C"].copy()

    df = df[np.isfinite(df["close"]) & (df["close"]>price_floor)]
    df = df[np.isfinite(df["K"])]
    df = df[(df["K"]>=K_range[0]) & (df["K"]<=K_range[1])]
    df = df[(df["T"]>=T_range[0]) & (df["T"]<=T_range[1])]

    S0 = float(meta.get("S0", np.nan))
    if np.isfinite(S0):
        df.loc[:, "close"] = df["close"].clip(lower=0.0, upper=price_cap_mult*S0)

    if drop_dupes and "conId" in df.columns:
        df = df.drop_duplicates(subset=["conId"]).copy()

    grp_key = "expiry_iso" if "expiry_iso" in df.columns else "T"
    cnt = df.groupby(grp_key)["K"].nunique()
    good = set(cnt[cnt>=min_strikes_per_expiry].index)
    df = df[df[grp_key].isin(good)].copy()

    sort_keys = ["expiry_iso","T","K"] if "expiry_iso" in df.columns else ["T","K"]
    df = df.sort_values(sort_keys).reset_index(drop=True)

    if enforce_monotonic_K and len(df):
        def _mono_fix(g):
            g = g.copy()
            g["close"] = np.minimum.accumulate(g["close"].to_numpy(float))
            return g
        gkeys = ["expiry_iso","T"] if "expiry_iso" in df.columns else ["T"]
        df = (df.groupby(gkeys, as_index=False, sort=False)
                .apply(_mono_fix)
                .reset_index(drop=True))

    df.to_csv(out_csv, index=False)

    if "T" not in df.columns:
        df = _ensure_T(df, meta)

    r=float(meta.get("r",0.0)); q=float(meta.get("q",0.0))
    Ts_present = np.sort(df["T"].unique())
    T_map = []
    for Tav in T_AVAILABLE:
        if Ts_present.size == 0:
            break
        j = int(np.argmin(np.abs(Ts_present - Tav)))
        Tmatch = float(Ts_present[j])
        if abs(Tmatch - Tav) <= T_tolerance and (Tmatch, Tav) not in T_map:
            T_map.append((Tmatch, Tav))

    rows = []
    for Tmatch, Tav in T_map:
        F = (S0 if np.isfinite(S0) else float(df["K"].median())) * exp((r-q)*Tmatch)
        mset = M_CORE if Tmatch < 1.0 else np.concatenate([M_CORE, M_WING])
        K_targets = np.clip(mset*F, K_range[0], K_range[1])

        dft = df[np.isclose(df["T"].values, Tmatch, rtol=0, atol=1e-6)].sort_values("K").copy()
        if dft.empty:
            continue
        Ks = dft["K"].to_numpy(float)

        chosen = set(); picks = []
        for Kt in K_targets:
            j = int(np.argmin(np.abs(Ks - Kt)))
            idx = dft.index[j]; bump=1
            while idx in chosen and (j-bump>=0 or j+bump<Ks.size):
                cand=[]
                if j-bump>=0:   cand.append((abs(Ks[j-bump]-Kt), dft.index[j-bump]))
                if j+bump<Ks.size: cand.append((abs(Ks[j+bump]-Kt), dft.index[j+bump]))
                if not cand: break
                idx = sorted(cand, key=lambda x: x[0])[0][1]
                bump+=1
            if idx not in chosen:
                chosen.add(idx); picks.append(idx)
        if picks:
            sel = dft.loc[sorted(picks)].copy()
            sel["T_req"] = Tav
            rows.append(sel)

    nodes = pd.concat(rows, axis=0).sort_values(["T","K"]).reset_index(drop=True) if rows else df.iloc[0:0].copy()
    nodes.to_csv(out_nodes_csv, index=False)

    report = {
        "S0": float(S0) if np.isfinite(S0) else None,
        "n_rows": int(len(df)),
        "n_expiries": int(df[grp_key].nunique()) if len(df) else 0,
        "K_min": float(df["K"].min()) if len(df) else None,
        "K_max": float(df["K"].max()) if len(df) else None,
        "T_min": float(df["T"].min()) if len(df) else None,
        "T_max": float(df["T"].max()) if len(df) else None,
        "expiries_kept_at_least": int(min_strikes_per_expiry),
        "calib_nodes": int(len(nodes)),
        "calib_Ts": int(nodes["T"].nunique()) if len(nodes) else 0
    }
    with open(out_report, "w") as f:
        json.dump(report, f, indent=2)

    print(f"[CLEAN] rows={report['n_rows']} expiries={report['n_expiries']} "
          f"K∈[{report['K_min']:.1f},{report['K_max']:.1f}] T∈[{report['T_min']:.3f},{report['T_max']:.3f}]")
    print(f"[NODES] selezionati {report['calib_nodes']} punti su {report['calib_Ts']} scadenze (tolleranza T=±{T_tolerance}y)")
    print(f"-> {out_csv}  /  {out_nodes_csv}  /  {out_report}")

    return df, report, nodes

if __name__ == "__main__":
    clean_chain_for_calibration()
# Out:
# [CLEAN] rows=1048 expiries=20 K∈[200.0,800.0] T∈[0.021,2.246]
# [NODES] selezionati 54 punti su 10 scadenze (tolleranza T=±0.05y)
# -> mstr_panel_calls_clean.csv  /  mstr_panel_calib_nodes.csv  /  mstr_panel_clean_report.json
# C:\Users\salvm\AppData\Local\Temp\ipykernel_13848\3623546528.py:123: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %% [markdown]
# ## FILTERING

# %%
# === FILTERING 1 ===
import json, numpy as np, pandas as pd

OUT_PREFIX = "mstr_panel"
df = pd.read_csv(f"{OUT_PREFIX}_chain.csv")
meta = json.load(open(f"{OUT_PREFIX}_meta.json"))
S0 = float(meta["S0"])

if "right" in df.columns:
    df = df[df["right"] == "C"].copy()

assert "T" in df.columns, "Manca la colonna T nel chain.csv"

pivot = (df.pivot_table(index="T", columns="K", values="close", aggfunc="mean")
           .sort_index().sort_index(axis=1))

T_min, T_max = 0.04, 3.00
K_min, K_max = 100.0, 900.0

volSurface = pivot.loc[(pivot.index >= T_min) & (pivot.index <= T_max),
                       (pivot.columns >= K_min) & (pivot.columns <= K_max)].copy()

while volSurface.isna().values.any() and not volSurface.empty:
    rows_with_nan = volSurface.index[volSurface.isna().any(axis=1)]
    cols_with_nan = volSurface.columns[volSurface.isna().any(axis=0)]
    volSurface.drop(index=rows_with_nan, columns=cols_with_nan, inplace=True, errors="ignore")

if volSurface.empty:
    raise ValueError("Tutto rimosso: nessun retticolo completo senza NaN con i filtri correnti.")

price_arr = volSurface.to_numpy()
maturities = volSurface.index.to_list()
common_strikes = volSurface.columns.to_list()

print("Number of common strikes:", len(common_strikes))
print("Shape:", price_arr.shape)
volSurface
# Out:
# Number of common strikes: 39
# Shape: (8, 39)
# K          150.0   160.0   170.0   180.0   190.0   200.0   210.0   220.0  \
# T
# 0.155365  138.75  129.25  119.88  110.62  101.48   92.51   83.77   75.25
# 0.232078  140.78  131.54  122.42  113.43  104.61   96.00   87.63   79.59
# 0.327968  143.35  134.37  125.56  116.90  108.45  100.23   92.32   84.68
# 0.404566  145.41  136.68  128.09  119.71  111.57  103.66   96.12   88.75
# 0.651142  151.36  143.31  135.37  127.69  120.28  113.17  106.28   99.65
# 0.903196  156.74  149.17  141.69  134.57  127.65  121.02  114.63  108.49
# 1.229338  163.45  156.36  149.56  142.95  136.63  130.57  124.58  119.04
# 2.149886  178.78  172.89  167.22  161.68  156.36  151.25  146.39  141.54
#
# K          230.0   240.0  ...  440.0  450.0  460.0  470.0  480.0  490.0  \
# T                         ...
# 0.155365   67.10   59.33  ...   3.51   3.26   3.02   2.81   2.63   2.47
# 0.232078   71.86   64.54  ...   6.06   5.59   5.18   4.80   4.48   4.20
# 0.327968   77.48   70.53  ...  10.00   9.30   8.65   8.07   7.55   7.11
# 0.404566   81.77   75.17  ...  13.45  12.52  11.70  11.00  10.32   9.74
# 0.651142   93.36   87.41  ...  23.90  22.62  21.42  20.33  19.33  18.42
# 0.903196  102.61   97.00  ...  33.75  32.28  30.89  29.57  28.24  27.20
# 1.229338  113.56  108.40  ...  45.77  44.09  42.41  40.83  39.40  38.13
# 2.149886  136.94  132.55  ...  73.89  72.03  70.32  68.65  66.98  65.31
#
# K         500.0  520.0  540.0  560.0
# T
# 0.155365   2.33   2.11   1.92   1.77
# 0.232078   3.96   3.54   3.20   2.92
# 0.327968   6.68   6.03   5.43   4.95
# 0.404566   9.24   8.27   7.48   6.83
# 0.651142  17.65  16.10  14.70  13.58
# 0.903196  26.15  24.17  22.42  20.85
# 1.229338  36.95  34.62  32.35  30.43
# 2.149886  63.64  60.31  58.02  55.73
#
# [8 rows x 39 columns]

# %%
# === FILTERING 2: nuova superficie filtrata (T>0.2, K ogni 3) ===
import numpy as np, pandas as pd, json

OUT_PREFIX = "mstr_panel"

def _ensure_volsurface_long_full():
    df = pd.read_csv(f"{OUT_PREFIX}_chain.csv")
    if "right" in df.columns:
        df = df[df["right"] == "C"].copy()

    colK  = "K" if "K" in df.columns else ("strike" if "strike" in df.columns else None)
    colPx = "close" if "close" in df.columns else ("price" if "price" in df.columns else None)
    if colK is None or colPx is None:
        raise KeyError("Mancano colonne strike/prezzo nel chain.csv")

    if "T" not in df.columns:
        meta = json.load(open(f"{OUT_PREFIX}_meta.json"))
        spot_ts = meta.get("spot_ts")
        if spot_ts is None:
            raise KeyError("Manca T e meta['spot_ts']")
        exp_col = None
        for c in ["expiry_iso","expiration","expiry","lastTradeDateOrContractMonth","expiryYmd"]:
            if c in df.columns:
                exp_col = c; break
        if exp_col is None:
            raise KeyError("Manca T e nessuna colonna expiry trovata")
        def _yearfrac_365(start_ts, end_ts):
            s = pd.to_datetime(start_ts, utc=True, errors="coerce")
            e = pd.to_datetime(end_ts,   utc=True, errors="coerce")
            return (e - s).total_seconds() / (365.0*24*3600.0)
        exp = df[exp_col].astype(str)
        mask_ymd = exp.str.fullmatch(r"\d{8}")
        exp2 = exp.copy()
        exp2.loc[mask_ymd] = exp.loc[mask_ymd] + " 16:00"
        mask_date = exp2.str.fullmatch(r"\d{4}-\d{2}-\d{2}")
        exp2.loc[mask_date] = exp2.loc[mask_date] + " 16:00"
        df = df.copy()
        df["T"] = exp2.apply(lambda x: _yearfrac_365(spot_ts, x))

    df = df.rename(columns={colK:"strike", colPx:"price"}).copy()

    long_full = (df[["T","strike","price"]]
                 .rename(columns={"T":"maturity"})
                 .dropna(subset=["maturity","strike","price"])
                 .astype({"maturity":float,"strike":float,"price":float})
                 .groupby(["maturity","strike"], as_index=False)["price"].mean())
    return long_full

if "volSurfaceLong_full" not in globals():
    volSurfaceLong_full = _ensure_volsurface_long_full()

def rate_fn(T: float) -> float:
    if "curve_fit" in globals():
        return float(curve_fit(float(T)))
    try:
        return float(RISK_FREE)
    except NameError:
        return 0.0

pivot_full = (volSurfaceLong_full
              .pivot_table(index="maturity", columns="strike", values="price", aggfunc="mean")
              .sort_index().sort_index(axis=1))

# ----- filtro griglia -----
T_cut = 0.30
K_min, K_max = 100.0, 900.0

rows_mask = pivot_full.index >= T_cut
all_K = pivot_full.columns.to_numpy(float)
mask_K = (all_K >= K_min) & (all_K <= K_max)
K_step = pd.Index(all_K[mask_K][::3], name=pivot_full.columns.name)

surf = pivot_full.loc[rows_mask, K_step.intersection(pivot_full.columns)].copy()

# rimozione iterativa NaN
while surf.isna().values.any() and not surf.empty:
    bad_rows = surf.index[surf.isna().any(axis=1)]
    bad_cols = surf.columns[surf.isna().any(axis=0)]
    surf.drop(index=bad_rows, columns=bad_cols, inplace=True, errors="ignore")

if surf.empty:
    raise ValueError("Nessun retticolo completo dopo il filtro T>0.2 e K ogni 3.")

volSurfaceFiltered = surf

# long + tassi
volSurfaceFilteredLong = volSurfaceFiltered.melt(ignore_index=False).reset_index()
volSurfaceFilteredLong.columns = ["maturity","strike","price"]
volSurfaceFilteredLong = volSurfaceFilteredLong.astype({"maturity":float,"strike":float,"price":float})
volSurfaceFilteredLong["rate"] = volSurfaceFilteredLong["maturity"].apply(rate_fn)

# report griglia
n_T, n_K = volSurfaceFiltered.shape
print(f"volSurfaceFiltered: {n_T} T × {n_K} K  -> punti = {n_T*n_K}")

# ----- export: chain_(numero-di-punti).csv -----
out = (volSurfaceFilteredLong
       .sort_values(["maturity","strike"], kind="mergesort")
       .reset_index(drop=True))

n_points = len(out)
# coerenza con la griglia
assert n_points == n_T * n_K, "Conteggio punti non coincide con n_T * n_K."

CHAIN_FILENAME = f"chain_data.csv"
out.to_csv(CHAIN_FILENAME, index=False)
print(f"Salvati {n_points} punti in {CHAIN_FILENAME}")
# Out:
# volSurfaceFiltered: 6 T × 14 K  -> punti = 84
# Salvati 84 punti in chain_data.csv

# %% [markdown]
# ## CALIBRAZIONE NO DEFAULT

# %%
# === CALIBRAZIONE HESTON (senza lambda) — chain_data + timing [FIX residui] ===
import numpy as np, pandas as pd, json, time, os, hashlib
from scipy.optimize import least_squares

OUT_PREFIX = "mstr_panel"
CHAIN_FILE = "chain_data.csv"

# --- util salvataggio robusto ---
def _save_json_atomic(path, obj):
    data = json.dumps(obj, indent=2)
    tmp = f"{path}.tmp"
    with open(tmp, "w", encoding="utf-8", newline="\n") as f:
        f.write(data)
    with open(tmp, "r", encoding="utf-8") as f:
        json.load(f)
    os.replace(tmp, path)

def _sha256(path):
    h = hashlib.sha256()
    with open(path, "rb") as f:
        for ch in iter(lambda: f.read(65536), b""):
            h.update(ch)
    return h.hexdigest()

# --- meta e dataset ---
meta = json.load(open(f"{OUT_PREFIX}_meta.json", "r", encoding="utf-8"))
S0 = float(meta["S0"])
vsl = pd.read_csv(CHAIN_FILE).dropna()
assert {"maturity","strike","price","rate"}.issubset(vsl.columns)
print(f"Calibrazione su {len(vsl)} punti da {CHAIN_FILE}")

K   = vsl["strike"].to_numpy(float)
tau = vsl["maturity"].to_numpy(float)
r   = vsl["rate"].to_numpy(float)
P   = vsl["price"].to_numpy(float)

# --- pricer veloce ---
def heston_price_rec_fast(S0, K, v0, kappaQ, thetaQ, xi, rho, tau, r, umax=50.0, N=3000):
    args = (S0, v0, kappaQ, thetaQ, xi, rho, tau, r)
    acc = 0.0
    dphi = umax / N
    for i in range(1, N):
        phi = dphi * (2*i + 1) / 2
        num = np.exp(r*tau)*heston_charfunc(phi-1j, *args) - K*heston_charfunc(phi, *args)
        den = 1j*phi*K**(1j*phi)
        acc += dphi * num/den
    return float(np.real((S0 - K*np.exp(-r*tau))/2 + acc/np.pi))

def price_vector_fast(S0, v0, kappaQ, thetaQ, xi, rho, K, tau, r):
    out = np.empty_like(K, dtype=float)
    for i in range(K.size):
        px = heston_price_rec_fast(S0, float(K[i]), v0, kappaQ, thetaQ, xi, rho,
                                   float(tau[i]), float(r[i]))
        out[i] = px if (np.isfinite(px) and px >= 0) else 1e9
    return out

# --- residui: penalità Feller sempre presente ---
w = 1.0 / np.maximum(P, 1.0)
PEN_SCALE = 10.0

def residuals(x):
    v0, kappaQ, thetaQ, xi, rho = map(float, x)
    model = price_vector_fast(S0, v0, kappaQ, thetaQ, xi, rho, K, tau, r)
    core = w * (model - P)
    feller_violation = max(0.0, xi*xi - 2.0*kappaQ*thetaQ)
    pen = PEN_SCALE * feller_violation
    return np.concatenate([core, np.array([pen], dtype=float)])

# --- ottimizzazione ---
x0 = np.array([0.60, 3.0, 0.10, 0.30, -0.60])
lb = np.array([1e-6,  0.05, 1e-6, 0.10, -0.999])
ub = np.array([0.95, 10.00, 0.90, 2.00,  0.999])

t0 = time.perf_counter()
res = least_squares(residuals, x0, bounds=(lb, ub),
                    loss="soft_l1", f_scale=5.0,
                    max_nfev=20000, xtol=1e-6, ftol=1e-6, verbose=1)
elapsed_sec = time.perf_counter() - t0

print("success:", res.success, " cost:", res.cost, " seconds:", f"{elapsed_sec:.3f}")

v0, kappaQ, thetaQ, xi, rho = map(float, res.x)
print("v0=%.6f  kappaQ=%.6f  thetaQ=%.6f  xi=%.6f  rho=%.6f" % (v0, kappaQ, thetaQ, xi, rho))

# --- ricalcolo accurato su chain_data (usa heston_price_rec lento) ---
P_fit = np.array([heston_price_rec(S0, float(K[i]), v0, kappaQ, thetaQ, xi, rho,
                                   float(tau[i]), float(r[i]))
                  for i in range(K.size)], dtype=float)
mae  = float(np.mean(np.abs(P - P_fit)))
rmse = float(np.sqrt(np.mean((P - P_fit)**2)))
print("MAE:", mae, "  RMSE:", rmse)

# --- salvataggio robusto ---
params = {"v0": v0, "kappaQ": kappaQ, "thetaQ": thetaQ,
          "xi": xi, "rho": rho, "S0": float(S0),
          "opt_cost": float(res.cost), "opt_seconds": float(elapsed_sec)}
base_path = f"{OUT_PREFIX}_heston_params.json"
_save_json_atomic(base_path, params)
print(f"[SAVE] -> {base_path} size={os.path.getsize(base_path)} sha256={_sha256(base_path)[:12]}")
# Out:
# Calibrazione su 84 punti da chain_data.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 75
#      72 ub = np.array([0.95, 10.00, 0.90, 2.00,  0.999])
#      74 t0 = time.perf_counter()
# ---> 75 res = least_squares(residuals, x0, bounds=(lb, ub),
#      76                     loss="soft_l1", f_scale=5.0,
#      77                     max_nfev=20000, xtol=1e-6, ftol=1e-6, verbose=1)
#      78 elapsed_sec = time.perf_counter() - t0
#      80 print("success:", res.success, " cost:", res.cost, " seconds:", f"{elapsed_sec:.3f}")
#
# File \\?\C:\Users\salvm\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\scipy\optimize\_lsq\least_squares.py:906, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     902                 J = np.atleast_2d(J)
#     904             return J
# --> 906         J0 = jac_wrapped(x0, f0)
#     908 if J0 is not None:
#     909     if J0.shape != (m, n):
#
# File \\?\C:\Users\salvm\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\scipy\optimize\_lsq\least_squares.py:898, in least_squares.<locals>.jac_wrapped(x, f)
#     897 def jac_wrapped(x, f):
# --> 898     J = approx_derivative(fun, x, rel_step=diff_step, method=jac,
#     899                           f0=f, bounds=bounds, args=args,
#     900                           kwargs=kwargs, sparsity=jac_sparsity)
#     901     if J.ndim != 2:  # J is guaranteed not sparse.
#     902         J = np.atleast_2d(J)
#
# File \\?\C:\Users\salvm\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\scipy\optimize\_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File \\?\C:\Users\salvm\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\scipy\optimize\_numdiff.py:592, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     590     x1[i] += h[i]
#     591     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 592     df = fun(x1) - f0
#     593 elif method == '3-point' and use_one_sided[i]:
#     594     x1[i] += h[i]
#
# File \\?\C:\Users\salvm\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\scipy\optimize\_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# Cell In[26], line 63, in residuals(x)
#      61 def residuals(x):
#      62     v0, kappaQ, thetaQ, xi, rho = map(float, x)
# ---> 63     model = price_vector_fast(S0, v0, kappaQ, thetaQ, xi, rho, K, tau, r)
#      64     core = w * (model - P)
#      65     feller_violation = max(0.0, xi*xi - 2.0*kappaQ*thetaQ)
#
# Cell In[26], line 52, in price_vector_fast(S0, v0, kappaQ, thetaQ, xi, rho, K, tau, r)
#      50 out = np.empty_like(K, dtype=float)
#      51 for i in range(K.size):
# ---> 52     px = heston_price_rec_fast(S0, float(K[i]), v0, kappaQ, thetaQ, xi, rho,
#      53                                float(tau[i]), float(r[i]))
#      54     out[i] = px if (np.isfinite(px) and px >= 0) else 1e9
#      55 return out
#
# Cell In[26], line 44, in heston_price_rec_fast(S0, K, v0, kappaQ, thetaQ, xi, rho, tau, r, umax, N)
#      42 for i in range(1, N):
#      43     phi = dphi * (2*i + 1) / 2
# ---> 44     num = np.exp(r*tau)*heston_charfunc(phi-1j, *args) - K*heston_charfunc(phi, *args)
#      45     den = 1j*phi*K**(1j*phi)
#      46     acc += dphi * num/den
#
# Cell In[10], line 24, in heston_charfunc(phi, S0, v0, kappaQ, thetaQ, xi, rho, tau, r)
#      22 exp1 = np.exp(r * phi * 1j * tau)
#      23 term2 = S0**(phi*1j) * ((1 - g*np.exp(d*tau)) / (1 - g))**(-2*a/xi**2)
# ---> 24 exp2 = np.exp(a*tau*(b - rspi + d)/xi**2 + v0*(b - rspi + d)*((1 - np.exp(d*tau))/(1 - g*np.exp(d*tau)))/xi**2)
#      25 return exp1 * term2 * exp2
#
# KeyboardInterrupt:

# %% [markdown]
# ## calbrazione nuova

# %%
# === CALIBRAZIONE HESTON (leastsq su prezzi) ===
import json, numpy as np, pandas as pd
from scipy.optimize import least_squares
from numpy.linalg import inv
from math import isfinite

USE_REC = True
UMAX = 100.0
NINT = 6000

CHAIN_FILENAME = "chain_data.csv"
META_JSON = "mstr_panel_meta.json"

try:
    meta = json.load(open(META_JSON))
    S0 = float(meta.get("S0"))
    q = float(meta.get("q", 0.0))
except Exception:
    tmp = pd.read_csv(CHAIN_FILENAME)
    S0 = float(tmp["strike"].median())
    q = 0.0

def _rate_fn_from_env(T):
    if "curve_fit" in globals():
        return float(curve_fit(float(T)))
    return 0.0

def load_chain(filename=CHAIN_FILENAME):
    df = pd.read_csv(filename).rename(columns={"maturity": "T", "strike": "K", "price": "Px"})
    need = {"T", "K", "Px"}
    if not need.issubset(df.columns):
        raise ValueError(f"chain_data.csv deve contenere {need}. Colonne viste: {df.columns.tolist()}")
    df = df.dropna(subset=["T", "K", "Px"]).astype({"T": float, "K": float, "Px": float})
    if "rate" not in df.columns:
        df["rate"] = df["T"].apply(_rate_fn_from_env)
    df = df[(df["Px"] > 0) & np.isfinite(df["rate"])]
    return df.sort_values(["T", "K"]).reset_index(drop=True)

chain = load_chain(CHAIN_FILENAME)

eps = 1e-8
w = 1.0 / np.maximum(chain["Px"].to_numpy(float), eps)

def price_vec(params):
    v0, kappa, theta, xi, rho = params
    out = np.empty(len(chain), float)
    Sdisc = S0
    for i, (K, T, r) in enumerate(zip(chain["K"].to_numpy(float),
                                      chain["T"].to_numpy(float),
                                      chain["rate"].to_numpy(float))):
        if USE_REC:
            out[i] = heston_price_rec(Sdisc, K, v0, kappa, theta, xi, rho, T, r, umax=UMAX, N=NINT)
        else:
            out[i] = heston_price(Sdisc, K, v0, kappa, theta, xi, rho, T, r)
    return out

# --- residui con vincolo di Feller ---
def residuals(params):
    v0, kappa, theta, xi, rho = params
    if (v0 <= 0) or (kappa <= 0) or (theta <= 0) or (xi <= 0) or (abs(rho) >= 1):
        return 1e6 * w
    feller = 2 * kappa * theta - xi**2
    if feller < 0:
        penalty = 1e6 * abs(feller)
        return penalty * w
    model = price_vec(params)
    return w * (model - chain["Px"].to_numpy(float))

# --- iniziali e bounds ---
x0 = np.array([
    min(0.05, np.var(np.diff(np.log(chain["K"].values + 1e-8))) * 10 + 0.04),
    1.0,     # kappa
    0.04,    # theta
    0.5,     # xi
    -0.5     # rho
], float)

lb = np.array([1e-4, 1e-3, 1e-4, 1e-3, -0.999])
ub = np.array([2.0, 20.0, 1.0, 2.0, 0.999])  # xi limitato a 2

res = least_squares(
    residuals, x0, bounds=(lb, ub),
    method="trf", xtol=1e-8, ftol=1e-8, gtol=1e-8, max_nfev=200
)

v0, kappa, theta, xi, rho = res.x
print("== Parametri ottimali ==")
print(f"v0   = {v0:.6f}")
print(f"kappa= {kappa:.6f}")
print(f"theta= {theta:.6f}")
print(f"xi   = {xi:.6f}")
print(f"rho  = {rho:.6f}")
print(f"n_points = {len(chain)}, nfev = {res.nfev}, status = {res.status}")

rel_err = (price_vec(res.x) - chain["Px"].to_numpy(float)) / np.maximum(chain["Px"].to_numpy(float), 1e-8)
rmse_rel = float(np.sqrt(np.mean(rel_err**2)))
print(f"RMSE relativo = {rmse_rel:.6e}")

try:
    J = res.jac
    n, p = J.shape
    JTJ = J.T @ J
    cov = (2 * res.cost / max(n - p, 1)) * inv(JTJ)
    sd = np.sqrt(np.clip(np.diag(cov), 0.0, np.inf))
    corr = cov / np.outer(sd, sd)
    param_names = ["v0", "kappa", "theta", "xi", "rho"]
    corr_df = pd.DataFrame(corr, index=param_names, columns=param_names)
    print("\n== Correlazioni tra stime dei parametri ==")
    print(corr_df.round(4))
except Exception as e:
    print("Correlazioni non disponibili:", e)

out_params = pd.Series(
    {"v0": v0, "kappa": kappa, "theta": theta, "xi": xi, "rho": rho, "rmse_rel": rmse_rel}
)
out_params.to_json("heston_params.json", indent=2)
try:
    corr_df.to_csv("heston_param_correlations.csv")
except Exception:
    pass

chk = chain.sample(min(10, len(chain)), random_state=1).copy()
chk["model_px"] = price_vec(res.x)[chk.index]
chk["rel_err"] = (chk["model_px"] - chk["Px"]) / chk["Px"].clip(lower=1e-8)
print("\nEsempi di fit (campione):")
print(chk[["T", "K", "Px", "model_px", "rel_err"]].round(6).to_string(index=False))
# Out:
# == Parametri ottimali ==
# v0   = 0.482530
# kappa= 2.519157
# theta= 0.275780
# xi   = 1.178757
# rho  = 0.461663
# n_points = 84, nfev = 53, status = 3
# RMSE relativo = 5.172935e-02
# Correlazioni non disponibili: Singular matrix
#
# Esempi di fit (campione):
#        T     K     Px   model_px   rel_err
# 0.330708 460.0   9.38   9.752898  0.039755
# 1.232078 490.0  38.61  38.650818  0.001057
# 1.232078 250.0 101.78  97.428901 -0.042750
# 0.653881 310.0  53.84  52.713116 -0.020930
# 2.152626 580.0  52.80  56.015729  0.060904
# 2.152626 370.0  88.28  86.266284 -0.022811
# 0.653881 340.0  43.94  43.867269 -0.001655
# 0.653881 460.0  22.15  22.903045  0.033998
# 0.905936 310.0  65.20  62.719642 -0.038042
# 1.232078 160.0 153.26 152.586438 -0.004395

# %% [markdown]
# ## ANALISI DEI RESIDUI

# %%
# === RESIDUI (base) su chain_data.csv usando mstr_panel_heston_params.json ===
import numpy as np, pandas as pd, json, os

OUT_PREFIX = "mstr_panel"
PARAMS_FILE = f"{OUT_PREFIX}_heston_params.json"
CHAIN_FILE = "chain_data.csv"
EPS = 1e-8

assert os.path.exists(PARAMS_FILE), f"{PARAMS_FILE} non trovato"
with open(PARAMS_FILE, "r", encoding="utf-8") as f:
    p = json.load(f)

S0     = float(p["S0"])
v0     = float(p["v0"])
kappaQ = float(p["kappaQ"])
thetaQ = float(p["thetaQ"])
xi     = float(p["xi"])
rho    = float(p["rho"])

vsl = pd.read_csv(CHAIN_FILE).dropna()
assert {"maturity","strike","price","rate"}.issubset(vsl.columns)

K = vsl["strike"].to_numpy(float)
T = vsl["maturity"].to_numpy(float)
r = vsl["rate"].to_numpy(float)
P = vsl["price"].to_numpy(float)

def _price_vector_acc(S0, v0, kappaQ, thetaQ, xi, rho, K, T, r):
    out = np.empty_like(K, dtype=float)
    for i in range(K.size):
        out[i] = heston_price_rec(S0, float(K[i]), v0, kappaQ, thetaQ, xi, rho,
                                  float(T[i]), float(r[i]))
    return out

price_fn = price_vector_fast if "price_vector_fast" in globals() else _price_vector_acc
Ph = price_fn(S0, v0, kappaQ, thetaQ, xi, rho, K, T, r)

df = vsl.copy()
df["heston_price"] = Ph
df["rel_err"] = np.abs(df["price"] - df["heston_price"]) / np.maximum(df["price"], EPS)

g = df.groupby("maturity", sort=True)
err_inf = g["rel_err"].max()
counts  = g.size()

err_table = (pd.DataFrame({"rel_err_inf": err_inf, "n_points": counts})
             .reset_index()
             .sort_values("maturity")
             .reset_index(drop=True))
err_table["rel_err_inf_pct"] = 100.0 * err_table["rel_err_inf"]

print(err_table)

rel_mae  = float(df["rel_err"].mean())
rel_rmse = float(np.sqrt((df["rel_err"]**2).mean()))
print("Rel MAE:", rel_mae, " Rel RMSE:", rel_rmse," (in % ->)", rel_mae*100, rel_rmse*100)
# Out:
#    maturity   rel_err_inf  n_points  rel_err_inf_pct
# 0  0.330708  2.008032e+08        14     2.008032e+10
# 1  0.407306  8.278702e-01        14     8.278702e+01
# 2  0.653881  4.468769e-01        14     4.468769e+01
# 3  0.905936  2.267669e-01        14     2.267669e+01
# 4  1.232078  6.835836e-02        14     6.835836e+00
# 5  2.152626  1.601974e-01        14     1.601974e+01
# Rel MAE: 2390514.5482740533  Rel RMSE: 21909426.621412374  (in % ->) 239051454.82740533 2190942662.1412373

# %% [markdown]
# ## Grafico surface

# %%
# === GRAFICI ===
import numpy as np
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode
import plotly.io as pio

init_notebook_mode(connected=True)
pio.renderers.default = "notebook_connected"

x = volSurfaceFilteredLong["maturity"].to_numpy(float)
y = volSurfaceFilteredLong["strike"].to_numpy(float)
z_mkt = volSurfaceFilteredLong["price"].to_numpy(float)
z_fit = volSurfaceFilteredLong["heston_price"].to_numpy(float)

fig = go.Figure()
fig.add_trace(go.Mesh3d(x=x, y=y, z=z_mkt, opacity=0.55, name="Market (mesh)"))
fig.add_trace(go.Scatter3d(x=x, y=y, z=z_fit, mode="markers", marker=dict(size=3), name="Heston (markers)"))

fig.update_layout(
    title_text="Market Prices (Mesh) vs Calibrated Heston Prices (Markers)",
    scene=dict(xaxis_title="TIME (Years)", yaxis_title="STRIKES (Pts)", zaxis_title="CALL PRICES"),
    height=800, width=900, legend=dict(x=0.02, y=0.98)
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File \\?\C:\Users\salvm\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'heston_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 13
#      11 y = volSurfaceFilteredLong["strike"].to_numpy(float)
#      12 z_mkt = volSurfaceFilteredLong["price"].to_numpy(float)
# ---> 13 z_fit = volSurfaceFilteredLong["heston_price"].to_numpy(float)
#      15 fig = go.Figure()
#      16 fig.add_trace(go.Mesh3d(x=x, y=y, z=z_mkt, opacity=0.55, name="Market (mesh)"))
#
# File \\?\C:\Users\salvm\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File \\?\C:\Users\salvm\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'heston_price'

# %% [markdown]
# ## Grafico surface from csv

# %%
# === READ FROM CSV ===
import json, os, numpy as np, pandas as pd
import plotly.graph_objects as go

CHAIN_FILE = "chain_data.csv"              # creato dal tuo pipeline
PARAMS_FILE = "mstr_panel_heston_params.json"  # salvato in calibrazione

df = pd.read_csv(CHAIN_FILE).dropna()
assert {"maturity","strike","price","rate"} <= set(df.columns)

# === HESTON PRICE: usa file già salvato se esiste, altrimenti calcola con i parametri ===
if os.path.exists("chain_with_heston.csv"):
    df = pd.read_csv("chain_with_heston.csv").dropna(subset=["maturity","strike","price"])
    assert "heston_price" in df.columns
else:
    assert os.path.exists(PARAMS_FILE), f"{PARAMS_FILE} mancante"
    p = json.load(open(PARAMS_FILE,"r"))
    S0, v0, kappaQ, thetaQ, xi, rho = map(float, (p["S0"], p["v0"], p["kappaQ"], p["thetaQ"], p["xi"], p["rho"]))

    # pricer veloce coerente col tuo codice
    def heston_charfunc(phi, S0, v0, kappaQ, thetaQ, xi, rho, tau, r):
        a = kappaQ*thetaQ
        b = kappaQ
        rspi = rho*xi*phi*1j
        d = np.sqrt((rspi - b)**2 + (phi*1j + phi**2)*xi**2)
        g = (b - rspi + d)/(b - rspi - d)
        exp1 = np.exp(r*phi*1j*tau)
        term2 = S0**(phi*1j) * ((1 - g*np.exp(d*tau))/(1 - g))**(-2*a/xi**2)
        exp2 = np.exp(a*tau*(b - rspi + d)/xi**2 + v0*(b - rspi + d)*((1 - np.exp(d*tau))/(1 - g*np.exp(d*tau)))/xi**2)
        return exp1*term2*exp2

    def heston_price_rec_fast(S0, K, v0, kappaQ, thetaQ, xi, rho, tau, r, umax=50.0, N=3000):
        args = (S0, v0, kappaQ, thetaQ, xi, rho, tau, r)
        acc = 0.0
        dphi = umax / N
        for i in range(1, N):
            phi = dphi*(2*i + 1)/2
            num = np.exp(r*tau)*heston_charfunc(phi-1j, *args) - K*heston_charfunc(phi, *args)
            den = 1j*phi*K**(1j*phi)
            acc += dphi * num/den
        return float(np.real((S0 - K*np.exp(-r*tau))/2 + acc/np.pi))

    Ks   = df["strike"].to_numpy(float)
    Taus = df["maturity"].to_numpy(float)
    Rs   = df["rate"].to_numpy(float)

    Ph = np.empty_like(Ks, dtype=float)
    for i in range(Ks.size):
        Ph[i] = heston_price_rec_fast(S0, float(Ks[i]), v0, kappaQ, thetaQ, xi, rho,
                                      float(Taus[i]), float(Rs[i]))
    df["heston_price"] = Ph
    df.to_csv("chain_with_heston.csv", index=False)

# === PLOT (da CSV) ===
# opzionale: filtri come in pipeline
T_cut = 0.30
K_min, K_max = 100.0, 900.0
plot_df = df[(df["maturity"]>=T_cut) & (df["strike"].between(K_min, K_max))].copy()

x = plot_df["maturity"].to_numpy(float)
y = plot_df["strike"].to_numpy(float)
z_mkt = plot_df["price"].to_numpy(float)
z_fit = plot_df["heston_price"].to_numpy(float)

fig = go.Figure()
fig.add_trace(go.Mesh3d(x=x, y=y, z=z_mkt, opacity=0.55, name="Market (mesh)"))
fig.add_trace(go.Scatter3d(x=x, y=y, z=z_fit, mode="markers", marker=dict(size=3), name="Heston (markers)"))
fig.update_layout(
    title_text="Market Prices (CSV) vs Calibrated Heston Prices",
    scene=dict(xaxis_title="TIME (Years)", yaxis_title="STRIKE", zaxis_title="CALL PRICE"),
    height=800, width=900, legend=dict(x=0.02, y=0.98)
)
fig.show()

# %% [raw]
# ## # === LETTURA PARAMETRI DA JSON IN ALTRI FILE ===
# import json
# OUT_PREFIX = "mstr_panel"
# with open(f"{OUT_PREFIX}_heston_params.json","r") as f:
#     params = json.load(f)
# # params["v0"], params["kappaQ"], params["thetaQ"], params["xi"], params["rho"]

# %% [markdown]
# ## calibrazione default

# %%
# === CALIBRAZIONE HESTON CON DEFAULT COSTANTE (λ fisso) — chain_data + xi≤2 + timing ===
# Richiede: heston_charfunc / heston_price_rec già definiti

import numpy as np, pandas as pd, json, time
from scipy.optimize import least_squares
from datetime import datetime

LAMBDA_DEFAULT = 0.035
OUT_PREFIX = "mstr_panel"
CHAIN_FILE = "chain_data.csv"

# --- S0 e dataset (98 punti) ---
meta = json.load(open(f"{OUT_PREFIX}_meta.json"))
S0 = float(meta["S0"])

vsl = pd.read_csv(CHAIN_FILE).dropna()
assert {"maturity","strike","price","rate"}.issubset(vsl.columns)
vsl = vsl.astype({"maturity":float,"strike":float,"price":float,"rate":float}).reset_index(drop=True)
vsl["rate_eff"] = vsl["rate"] + LAMBDA_DEFAULT
print(f"Calibrazione default su {len(vsl)} punti da {CHAIN_FILE} | λ={LAMBDA_DEFAULT}")

K     = vsl["strike"].to_numpy(float)
tau   = vsl["maturity"].to_numpy(float)
r_eff = vsl["rate_eff"].to_numpy(float)
P     = vsl["price"].to_numpy(float)

# --- pricer veloce (usa r_eff) ---
def heston_price_rec_fast_default(S0, K, v0, kappaQ, thetaQ, xi, rho, tau, r_eff, umax=50.0, N=3000):
    args = (S0, v0, kappaQ, thetaQ, xi, rho, tau, r_eff)
    acc = 0.0
    dphi = umax / N
    for i in range(1, N):
        phi = dphi * (2*i + 1) / 2
        num = np.exp(r_eff*tau)*heston_charfunc(phi-1j, *args) - K*heston_charfunc(phi, *args)
        den = 1j*phi*K**(1j*phi)
        acc += dphi * num/den
    return float(np.real((S0 - K*np.exp(-r_eff*tau))/2 + acc/np.pi))

def price_vector_fast_default(S0, v0, kappaQ, thetaQ, xi, rho, K, tau, r_eff):
    out = np.empty_like(K, dtype=float)
    for i in range(K.size):
        px = heston_price_rec_fast_default(S0, float(K[i]), v0, kappaQ, thetaQ, xi, rho,
                                           float(tau[i]), float(r_eff[i]))
        out[i] = px if (np.isfinite(px) and px >= 0) else 1e9
    return out

# --- residui e ottimizzazione (xi ≤ 2) ---
w = 1.0 / np.maximum(P, 1.0)
def residuals(x):
    v0, kappaQ, thetaQ, xi, rho = map(float, x)
    model = price_vector_fast_default(S0, v0, kappaQ, thetaQ, xi, rho, K, tau, r_eff)
    return w * (model - P)

x0 = np.array([0.50, 2.5, 0.08, 0.30, -0.20])
lb = np.array([1e-6,  0.05, 1e-6, 0.10, -0.999])
ub = np.array([0.95, 12.00, 0.90, 2.00,  0.999])  # xi max = 2.00

t0 = time.perf_counter()
res = least_squares(residuals, x0, bounds=(lb, ub),
                    loss="soft_l1", f_scale=5.0,
                    max_nfev=20000, xtol=1e-6, ftol=1e-6, verbose=1)
elapsed_sec = time.perf_counter() - t0

print("success:", res.success, " cost:", res.cost, " seconds:", f"{elapsed_sec:.3f}")
v0, kappaQ, thetaQ, xi, rho = res.x
print("PARAMS (λ fisso): v0=%.6f  kappaQ=%.6f  thetaQ=%.6f  xi=%.6f  rho=%.6f" % (v0, kappaQ, thetaQ, xi, rho))

# --- ricalcolo accurato su tutti i punti con r_eff ---
P_fit = np.array([heston_price_rec(S0, float(K[i]), v0, kappaQ, thetaQ, xi, rho,
                                   float(tau[i]), float(r_eff[i]))
                  for i in range(K.size)], dtype=float)
mae  = float(np.mean(np.abs(P - P_fit)))
rmse = float(np.sqrt(np.mean((P - P_fit)**2)))
rel_mae  = float(np.mean(np.abs(P - P_fit) / np.maximum(P, 1e-8)))
rel_rmse = float(np.sqrt(np.mean(((P - P_fit)/np.maximum(P,1e-8))**2)))
print("MAE:", mae, " RMSE:", rmse, "  Rel MAE%:", 100*rel_mae, "  Rel RMSE%:", 100*rel_rmse)

# --- salvataggi JSON con timing ---
params = {
    "v0": float(v0), "kappaQ": float(kappaQ), "thetaQ": float(thetaQ),
    "xi": float(xi), "rho": float(rho),
    "lambda_default": float(LAMBDA_DEFAULT), "S0": float(S0),
    "pricing_rate": "r + lambda_default",
    "opt_cost": float(res.cost), "opt_seconds": float(elapsed_sec)
}
with open(f"{OUT_PREFIX}_heston_params_default.json", "w") as f:
    json.dump(params, f, indent=2)
print(f"[SAVE] -> {OUT_PREFIX}_heston_params_default.json")

params_default = {
    "model": "Heston",
    "as_of": datetime.utcnow().isoformat() + "Z",
    "S0": float(S0),
    "lambda_default": float(LAMBDA_DEFAULT),
    "pricing_rate": "r + lambda_default",
    "v0": float(v0), "kappaQ": float(kappaQ), "thetaQ": float(thetaQ),
    "xi": float(xi), "rho": float(rho),
    "opt_cost": float(res.cost), "opt_seconds": float(elapsed_sec)
}
with open("parameters_default.json", "w") as f:
    json.dump(params_default, f, indent=2)
print("[SAVE] -> parameters_default.json")
# Out:
# Calibrazione default su 84 punti da chain_data.csv | λ=0.035
# `xtol` termination condition is satisfied.
# Function evaluations 25, initial cost 5.1882e+00, final cost 1.4263e-01, first-order optimality 3.87e-01.
# success: True  cost: 0.1426345141031793  seconds: 455.352
# PARAMS (λ fisso): v0=0.493522  kappaQ=2.389390  thetaQ=0.170109  xi=1.194271  rho=0.503653
# MAE: 2.984008455111671  RMSE: 4.125106709137833   Rel MAE%: 4.89496511594732   Rel RMSE%: 5.7491551880544955
# [SAVE] -> mstr_panel_heston_params_default.json
# [SAVE] -> parameters_default.json
# C:\Users\salvm\AppData\Local\Temp\ipykernel_13848\2168385052.py:92: DeprecationWarning:
#
# datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).

# %% [markdown]
# ## residui default

# %%
# === ANALISI RESIDUI: HESTON λ fisso (r_eff = r + λ) ===
import numpy as np, pandas as pd, json

# prerequisiti: v0,kappaQ,thetaQ,xi,rho, LAMBDA_DEFAULT, S0, volSurfaceFilteredLong, heston_price_rec

# 1) prepara dataset e r_eff
assert {"maturity","strike","price","rate"}.issubset(volSurfaceFilteredLong.columns), "Manca volSurfaceFilteredLong completo."
df = (volSurfaceFilteredLong
      .loc[:, ["maturity","strike","price","rate"]]
      .dropna()
      .astype({"maturity":float,"strike":float,"price":float,"rate":float})
      .reset_index(drop=True))
df["rate_eff"] = df["rate"] + float(LAMBDA_DEFAULT)

# 2) prezzi Heston su r_eff
K_arr = df["strike"].to_numpy(float)
T_arr = df["maturity"].to_numpy(float)
r_arr = df["rate_eff"].to_numpy(float)

Ph = np.empty_like(K_arr, dtype=float)
for i in range(K_arr.size):
    Ph[i] = heston_price_rec(S0, float(K_arr[i]), float(v0), float(kappaQ), float(thetaQ),
                             float(xi), float(rho), float(T_arr[i]), float(r_arr[i]))

df["heston_price"] = Ph

# 3) residui assoluti e relativi
eps = 1e-8
P  = df["price"].to_numpy(float)
df["abs_resid"] = P - df["heston_price"]
df["rel_resid"] = df["abs_resid"] / np.maximum(P, eps)
df["abs_err"]   = np.abs(df["abs_resid"])
df["rel_err"]   = np.abs(df["rel_resid"])

# 4) metriche globali
mae       = float(df["abs_err"].mean())
rmse      = float(np.sqrt(((df["abs_resid"])**2).mean()))
bias      = float(df["abs_resid"].mean())
rel_mae   = float(df["rel_err"].mean())
rel_rmse  = float(np.sqrt((df["rel_resid"]**2).mean()))
rel_bias  = float(df["rel_resid"].mean())

print(f"[GLOBAL]  MAE={mae:.6f}  RMSE={rmse:.6f}  Bias={bias:.6f}  |  RelMAE={100*rel_mae:.3f}%  RelRMSE={100*rel_rmse:.3f}%  RelBias={100*rel_bias:.3f}%")

# 5) riepilogo per maturità (∞-norma relativa + conteggi + bias)
grpT = df.groupby("maturity", sort=True)
err_T = (pd.DataFrame({
            "rel_err_inf": grpT["rel_err"].max(),
            "rel_err_mean": grpT["rel_err"].mean(),
            "bias": grpT["abs_resid"].mean(),
            "n_points": grpT.size()
        })
        .reset_index()
        .sort_values("maturity"))
err_T["rel_err_inf_pct"]  = 100.0 * err_T["rel_err_inf"]
err_T["rel_err_mean_pct"] = 100.0 * err_T["rel_err_mean"]
print("\n[BY MATURITY]\n", err_T)

# 6) riepilogo per strike
grpK = df.groupby("strike", sort=True)
err_K = (pd.DataFrame({
            "rel_err_inf": grpK["rel_err"].max(),
            "rel_err_mean": grpK["rel_err"].mean(),
            "bias": grpK["abs_resid"].mean(),
            "n_points": grpK.size()
        })
        .reset_index()
        .sort_values("strike"))
err_K["rel_err_inf_pct"]  = 100.0 * err_K["rel_err_inf"]
err_K["rel_err_mean_pct"] = 100.0 * err_K["rel_err_mean"]
print("\n[BY STRIKE]\n", err_K.head(20))  # stampa breve

# 7) matrici pivot utili per heatmap
resid_surface_abs = (df.pivot_table(index="maturity", columns="strike", values="abs_resid", aggfunc="mean")
                      .sort_index().sort_index(axis=1))
resid_surface_rel = (df.pivot_table(index="maturity", columns="strike", values="rel_resid", aggfunc="mean")
                      .sort_index().sort_index(axis=1))

# 8) salvataggi
OUT_PREFIX = OUT_PREFIX if "OUT_PREFIX" in globals() else "mstr_panel"
df.to_csv(f"{OUT_PREFIX}_residuals_default_full.csv", index=False)
err_T.to_csv(f"{OUT_PREFIX}_residuals_default_by_maturity.csv", index=False)
err_K.to_csv(f"{OUT_PREFIX}_residuals_default_by_strike.csv", index=False)

summary = {
    "lambda_default": float(LAMBDA_DEFAULT),
    "global": {
        "MAE": mae, "RMSE": rmse, "Bias": bias,
        "RelMAE_pct": 100*rel_mae, "RelRMSE_pct": 100*rel_rmse, "RelBias_pct": 100*rel_bias
    },
    "counts": int(len(df)),
    "unique_maturities": int(df["maturity"].nunique()),
    "unique_strikes": int(df["strike"].nunique())
}
with open(f"{OUT_PREFIX}_residuals_default_summary.json", "w") as f:
    json.dump(summary, f, indent=2)

print(f"\n[SAVE] CSV completi e summary JSON in:\n  {OUT_PREFIX}_residuals_default_full.csv\n  {OUT_PREFIX}_residuals_default_by_maturity.csv\n  {OUT_PREFIX}_residuals_default_by_strike.csv\n  {OUT_PREFIX}_residuals_default_summary.json")

# 9) (opzionale) heatmap rapide con matplotlib
try:
    import matplotlib.pyplot as plt
    import numpy as np

    # heatmap residuo relativo (%)
    plt.figure(figsize=(10,6))
    plt.imshow(100*np.array(resid_surface_rel), aspect="auto", origin="lower",
               extent=[resid_surface_rel.columns.min(), resid_surface_rel.columns.max(),
                       resid_surface_rel.index.min(), resid_surface_rel.index.max()])
    plt.colorbar(label="Residual (%)")
    plt.xlabel("Strike")
    plt.ylabel("Maturity (years)")
    plt.title("Relative Residual Heatmap (r + λ)")
    plt.tight_layout()
    plt.show()
except Exception as e:
    print("[PLOT] skipped:", e)
# Out:
# [GLOBAL]  MAE=2.984008  RMSE=4.125107  Bias=-1.939472  |  RelMAE=4.895%  RelRMSE=5.749%  RelBias=-2.632%
#
# [BY MATURITY]
#     maturity  rel_err_inf  rel_err_mean      bias  n_points  rel_err_inf_pct  \
# 0  0.330708     0.118187      0.070126 -2.161450        14        11.818696
# 1  0.407306     0.077081      0.044347 -1.815329        14         7.708082
# 2  0.653881     0.083261      0.025227 -1.104578        14         8.326137
# 3  0.905936     0.068660      0.034446  0.045819        14         6.865986
# 4  1.232078     0.081116      0.044612  0.101022        14         8.111642
# 5  2.152626     0.102999      0.074942 -6.702317        14        10.299937
#
#    rel_err_mean_pct
# 0          7.012564
# 1          4.434658
# 2          2.522687
# 3          3.444554
# 4          4.461173
# 5          7.494155
#
# [BY STRIKE]
#      strike  rel_err_inf  rel_err_mean      bias  n_points  rel_err_inf_pct  \
# 0    160.0     0.081116      0.063000 -9.292898         6         8.111642
# 1    190.0     0.054095      0.041694 -5.136536         6         5.409485
# 2    220.0     0.037706      0.022406 -2.263100         6         3.770578
# 3    250.0     0.037348      0.018227 -1.005293         6         3.734846
# 4    280.0     0.058996      0.032937 -0.831454         6         5.899601
# 5    310.0     0.068777      0.045313 -0.657047         6         6.877658
# 6    340.0     0.092740      0.056628 -0.825142         6         9.274035
# 7    370.0     0.113825      0.066031 -0.947177         6        11.382495
# 8    400.0     0.111263      0.066728 -1.015443         6        11.126257
# 9    430.0     0.118187      0.068927 -0.968584         6        11.818696
# 10   460.0     0.100449      0.055705 -0.949188         6        10.044943
# 11   490.0     0.095904      0.040889 -0.950171         6         9.590360
# 12   520.0     0.096124      0.039280 -1.045596         6         9.612392
# 13   580.0     0.117107      0.067529 -1.264981         6        11.710652
#
#     rel_err_mean_pct
# 0           6.300017
# 1           4.169424
# 2           2.240632
# 3           1.822707
# 4           3.293735
# 5           4.531270
# 6           5.662825
# 7           6.603112
# 8           6.672770
# 9           6.892687
# 10          5.570529
# 11          4.088922
# 12          3.928000
# 13          6.752881
#
# [SAVE] CSV completi e summary JSON in:
#   mstr_panel_residuals_default_full.csv
#   mstr_panel_residuals_default_by_maturity.csv
#   mstr_panel_residuals_default_by_strike.csv
#   mstr_panel_residuals_default_summary.json
